# %% [markdown]
# # Hello world!

# %%
# this is some code

print(hello world!)
# Out:
#   Cell In[1], line 3
#     print(hello world!)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
